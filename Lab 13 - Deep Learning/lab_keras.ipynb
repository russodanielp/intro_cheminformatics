# %% [markdown]
# # Deep Learning

# %% [markdown]
# ## Aim
#
# To understand the basics of a neural network and to create a simple deep learning neural network using PyTorch.
#
# ## Objectives
#
# * Create a simple deep learning model using Keras and Tensorflow
#
# ## Background
#
# The explosion of the amounts of accessible, publically available data couples with hardware advances such as graphical processing units (GPUs) has lead to the resurgances of deep learning methods.  Deep learning is a catch-all term for various types of artificial neural networks, which have seen in the QSAR lab.  A simple neural network generally consists of one input later, 1 or more hidden layers, and an output layer (__Figure 1__).  However, this framework can be extended to include any number of hidden layers.  When an artificial neural network contains more than 1 hidden layer, it is called a deep neural network.
#
# <center><img src="img/deeplearning.png" style="width: 600px;"></img><br><strong>Figure 1.</strong>  A Simple Neural Network.</center>
#
# Part of Python's popularity is the number of deep learning libraries.  The [Keras](https://www.google.com/search?q=keras&oq=keras+&aqs=chrome..69i57j69i65l3j69i60l4.3219j0j7&sourceid=chrome&ie=UTF-8) is one of the most popular and is built with Google's [Tensorflow](https://www.tensorflow.org/).  Here we will use them in this lab to create a fairly standard neural network of 3 hidden layers.
#
#
# In this lab we will use a dataset provided by the dataset provided by [NICEATM Acute Oral Toxicity challenge](https://ehp.niehs.nih.gov/doi/10.1289/EHP8495).  In this challenge, over 11,000 chemicals with acute oral toxicity values LD$_{50}$, which is defined as the median concentraion at which 50% of the tested animal subjects die after substance ingestion.  Of these chemicals a training set what provided to modeling participants (labeled `TrainingSet.sdf` in the `data` folder).  We will use this to create a neural network using PyTorch.

# %%
import numpy as np
import torch
import tensorflow as tf
from rdkit.ML.Descriptors import MoleculeDescriptors
from rdkit.Chem import AllChem
from rdkit.Chem import MACCSkeys
from rdkit.Chem import Descriptors
from rdkit import Chem
import pandas as pd
from rdkit.Chem import PandasTools
import math

# %% [markdown]
# ## Data Preperation
#
# We can prepare the data just as we have for our QSAR methods.

# %%
def calc_fp_from_mol(mol, method="maccs", n_bits=2048):
    """
    Encode a molecule from a RDKit Mol into a fingerprint.

    Parameters
    ----------
    mol : RDKit Mol
        The RDKit molecule.

    method : str
        The type of fingerprint to use. Default is MACCS keys.

    n_bits : int
        The length of the fingerprint.

    Returns
    -------
    array
        The fingerprint array.

    """

    if method == "maccs":
        return list(MACCSkeys.GenMACCSKeys(mol))
    if method == "morgan4":
        return list(AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=n_bits))
    if method == "morgan6":
        return list(AllChem.GetMorganFingerprintAsBitVect(mol, 3, nBits=n_bits))
    else:
        # NBVAL_CHECK_OUTPUT
        print(f"Warning: Wrong method specified: {method}. Default will be used instead.")
        return list(MACCSkeys.GenMACCSKeys(mol))

# %%
df = PandasTools.LoadSDF('data/TrainingSet.sdf')
df.head(3)
# Out:
# RDKit WARNING: [12:33:28] Warning: molecule is tagged as 3D, but all Z coords are zero
# [12:33:28] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [12:33:28] Warning: molecule is tagged as 3D, but all Z coords are zero
# [12:33:28] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [12:33:28] Warning: molecule is tagged as 3D, but all Z coords are zero
# [12:33:28] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [12:33:29] Warning: molecule is tagged as 3D, but all Z coords are zero
# [12:33:29] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [12:33:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# [12:33:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [12:33:32] Warning: molecule is tagged as 3D, but all Z coords are zero
# [12:33:32] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [12:33:32] Warning: molecule is tagged as 3D, but all Z coords are zero
# [12:33:32] Warning: molecule is tagged as 3D, but all Z coords are zero
#          CASRN DTXSID Name     Structure_Source very_toxic nontoxic LD50_mgkg  \
# 0    7545-48-4              Public_CrossChecked      FALSE     TRUE   12000.0
# 1  134528-32-8              Public_CrossChecked      FALSE     TRUE
# 2   17902-23-7              Public_CrossChecked      FALSE    FALSE     930.0
#
#   EPA_category GHS_category  \
# 0            4            5
# 1            3            5
# 2            3            4
#
#                                      Original_SMILES  \
# 0  C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)([O-])[O-])...
# 1          C1=C(C(=O)NC(=O)N1C2C(C(C(O2)CO)O)O)C=CBr
# 2                        C1CC(OC1)N2C=C(C(=O)NC2=O)F
#
#                            Canonical_QSARr  \
# 0  OC1C(COP(O)(O)=O)OC(C1O)N1C=CC(=O)NC1=O
# 1    OCC1OC(C(O)C1O)N1C=C(C=CBr)C(=O)NC1=O
# 2                O=C1NC(=O)C(F)=CN1C1CCCO1
#
#                                     InChI_Code_QSARr  \
# 0  InChI=1S/C9H13N2O9P/c12-5-1-2-11(9(15)10-5)8-7...
# 1  InChI=1S/C11H13BrN2O6/c12-2-1-5-3-14(11(19)13-...
# 2  InChI=1S/C8H9FN2O3/c9-5-4-11(6-2-1-3-14-6)8(13...
#
#                InChI Key_QSARr Salt_Solvent Conv_Info            Enrg_Info  \
# 0  DJJCXFVJDGTHFX-UHFFFAOYSA-N  [Na+].[Na+]      true  -211.68226084448955
# 1  GCQYYIHYQMVWLT-UHFFFAOYSA-N            ?      true   2.7756185873526507
# 2  WFWLQNSHRPWKFK-UHFFFAOYSA-N            ?      true   -70.26435136661355
#
#       ID                                              ROMol
# 0  17743  <img data-content="rdkit/molecule" src="data:i...
# 1  10555  <img data-content="rdkit/molecule" src="data:i...
# 2  15003  <img data-content="rdkit/molecule" src="data:i...

# %% [markdown]
# Let's remove data without LD$_{50}$ data.

# %%
df = df[df.LD50_mgkg != '']
df['LD50_mgkg'] = df['LD50_mgkg'].astype(float)
df.head()
# Out:
#         CASRN DTXSID Name     Structure_Source very_toxic nontoxic  LD50_mgkg  \
# 0   7545-48-4              Public_CrossChecked      FALSE     TRUE    12000.0
# 2  17902-23-7              Public_CrossChecked      FALSE    FALSE      930.0
# 3  27942-00-3              Public_CrossChecked      FALSE     TRUE     8150.0
# 5  80834-51-1              Public_CrossChecked      FALSE    FALSE      500.0
# 6  80834-80-6              Public_CrossChecked      FALSE    FALSE      500.0
#
#   EPA_category GHS_category  \
# 0            4            5
# 2            3            4
# 3            4            5
# 5            2            4
# 6            2            4
#
#                                      Original_SMILES  \
# 0  C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)([O-])[O-])...
# 2                        C1CC(OC1)N2C=C(C(=O)NC2=O)F
# 3                                   CN1C=CC(=O)NC1=O
# 5  CCC(C(=O)C1=CC2=C(C=C1)NC(=O)C=C2)N3CCN(CC3)C4...
# 6  CCOC1=CC=CC=C1N2CCN(CC2)CCC=CC3=CC4=C(C=C3)NC(...
#
#                                      Canonical_QSARr  \
# 0            OC1C(COP(O)(O)=O)OC(C1O)N1C=CC(=O)NC1=O
# 2                          O=C1NC(=O)C(F)=CN1C1CCCO1
# 3                                   CN1C=CC(=O)NC1=O
# 5  CCC(C(=O)c1cc2C=CC(=O)Nc2cc1)N1CCN(CC1)c1cc(Cl...
# 6      CCOc1ccccc1N1CCN(CCC=Cc2cc3C=CC(=O)Nc3cc2)CC1
#
#                                     InChI_Code_QSARr  \
# 0  InChI=1S/C9H13N2O9P/c12-5-1-2-11(9(15)10-5)8-7...
# 2  InChI=1S/C8H9FN2O3/c9-5-4-11(6-2-1-3-14-6)8(13...
# 3  InChI=1S/C5H6N2O2/c1-7-3-2-4(8)6-5(7)9/h2-3H,1...
# 5  InChI=1S/C23H24ClN3O2/c1-2-21(23(29)17-6-8-20-...
# 6  InChI=1S/C25H29N3O2/c1-2-30-24-9-4-3-8-23(24)2...
#
#                InChI Key_QSARr Salt_Solvent Conv_Info            Enrg_Info  \
# 0  DJJCXFVJDGTHFX-UHFFFAOYSA-N  [Na+].[Na+]      true  -211.68226084448955
# 2  WFWLQNSHRPWKFK-UHFFFAOYSA-N            ?      true   -70.26435136661355
# 3  XBCXJKGHPABGSD-UHFFFAOYSA-N            ?      true   -87.22216620737237
# 5  LVCUAMMHDAVDEZ-UHFFFAOYSA-N            ?      true    144.6181349380037
# 6  WTQXWMCWQHOPRX-UHFFFAOYSA-N            ?      true   137.79606898256017
#
#       ID                                              ROMol
# 0  17743  <img data-content="rdkit/molecule" src="data:i...
# 2  15003  <img data-content="rdkit/molecule" src="data:i...
# 3  17566  <img data-content="rdkit/molecule" src="data:i...
# 5  14260  <img data-content="rdkit/molecule" src="data:i...
# 6  14279  <img data-content="rdkit/molecule" src="data:i...

# %%
desc_list = []


for mol in df.ROMol.tolist():
    desc = calc_fp_from_mol(mol, method='morgan6', n_bits=1024)
    desc_list.append(desc)

    
X = pd.DataFrame(desc_list)
y = df['LD50_mgkg'].astype(float).apply(lambda x: math.log10(x))

# %%
# %matplotlib inline

# %%
ax = y.hist(bins=100, edgecolor='k', lw=4, facecolor=(1, 0, 0, 1), figsize=(10,5), xrot=90, density=True, label='distribution')
y.hist(cumulative=True, density=1, bins=100, label='cumulative', zorder=0, facecolor=(0.8, 0.8, 0.8, 0.4), edgecolor='k', lw=2, figsize=(10,5))
ax.axhline(0.5, ls='--', c='k')
ax.legend()
ax
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above plot shows that about half the LD50 data points lie above a log(3) and half lie below, so we can use that as our activitiy classification cutoffs.
#
# We need to validate our model.  A typical DNN is usually trained on hundreds to thousands of data points and need to optimize millions of parameters.  For this type of scenario, cross validation as we did in the QSAR lab, would require splitting our data into multiple tests sets, which is often not practical without the help of a (or several) GPU(s).
#
# For validation, we will split our data into a validation set consisting of 20% of our compounds.

# %%
from sklearn.model_selection import KFold, train_test_split
SEED = 2008


y_binary = y.copy()
y_binary[y < 3] = 1
y_binary[y >= 3] = 0

# from sklearn.preprocessing import OneHotEncoder

# enc = OneHotEncoder(handle_unknown='ignore')

# y_binary = enc.fit_transform(y_binary.values.reshape(-1, 1)).toarray()

X_train, X_val, y_train, y_val = train_test_split(X, y_binary , test_size=0.2, random_state=SEED)

X_train, X_val, y_train, y_val = X_train.values.astype('float32'), X_val.values.astype('float32'), y_train.values.astype('float32'), y_val.values.astype('float32')

# %% [markdown]
# ## Model Building
#
# There are 2 different ways to build NNs in keras, the Sequential and Functional models.  The [sequential model](https://keras.io/guides/sequential_model/) is usually good for simple tasks and more intuitive. From the docs:
# A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor.
#
# A Sequential model is not appropriate when:
#
# * Your model has multiple inputs or multiple outputs
# * Any of your layers has multiple inputs or multiple outputs
# * You need to do layer sharing
# * You want non-linear topology (e.g. a residual connection, a multi-branch model)
#
# In this model we just simple create the layers and define the number of nodes and the activation function we want to use.

# %%
# this layer is not need, but
# good to explicitly say input 
# shape
input_layer = tf.keras.layers.Input(shape=(X_train.shape[1],))

# create layers 1-3
layer1 = tf.keras.layers.Dense(1000, activation="relu")
dropout1 = tf.keras.layers.Dropout(0.2)
layer2 = tf.keras.layers.Dense(1000, activation="relu")
dropout2 = tf.keras.layers.Dropout(0.2)
layer3 = tf.keras.layers.Dense(1000, activation="relu")
dropout3 = tf.keras.layers.Dropout(0.2)

# output 
output = tf.keras.layers.Dense(1, activation="sigmoid")

# %% [markdown]
# We then create a `Sequential()` model and `add` them.

# %%
layers = [input_layer, layer1, dropout1, layer2, dropout2, layer3, dropout3, output]

model = tf.keras.Sequential(layers)
print(model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 1000)              1025000
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1000)              1001000
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1000)              1001000
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 1001
# =================================================================
# Total params: 3,028,001
# Trainable params: 3,028,001
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Note:  you can also add them by the follow code:
#
# ```
# model = tf.keras.Sequential()
# model.add(layer1)
# model.add(layer2)
# model.add(layer3)
# model.add(output)
#
# ```

# %% [markdown]
# We need to tell keras about the optimize algorithm (there are many besides SGD) and which loss function to use, which in our case is [binary cross entropy](https://en.wikipedia.org/wiki/Binary_entropy_function).

# %%
model.compile(optimizer="SGD", loss="binary_crossentropy")

# %% [markdown]
# ## Model training
#
# Model training a neural network works by taking epochs, also known as steps.  Mathematically, it is an optimization problem where we are trying to find the neural network parameters which minimize the loss function.  In this case our loss function is binary cross entroy, which is how well our model is predicting our classes (0, 1).  After every epoch, the loss is calculated and for each parameters some calculus is applied to figure our which way we should adjust these parameters such that the loss will be lower the next epoch.  This is usually repeated until some specified number of training epochs or some other stopping point.
#
# __NOTE:__  Depending on the your CPU hardware, training the model by running the cell below could take a significant time period.

# %%
EPOCHS = 50

model.fit(X_train, y_train, epochs=EPOCHS, validation_data=(X_val, y_val))
# Out:
# Train on 5387 samples, validate on 1347 samples
# Epoch 1/50
# 5387/5387 [==============================] - 4s 734us/sample - loss: 0.6899 - val_loss: 0.6887
# Epoch 2/50
# 5387/5387 [==============================] - 3s 538us/sample - loss: 0.6852 - val_loss: 0.6820
# Epoch 3/50
# 5387/5387 [==============================] - 3s 541us/sample - loss: 0.6765 - val_loss: 0.6757
# Epoch 4/50
# 5387/5387 [==============================] - 3s 550us/sample - loss: 0.6701 - val_loss: 0.6675
# Epoch 5/50
# 5387/5387 [==============================] - 3s 532us/sample - loss: 0.6603 - val_loss: 0.6584
# Epoch 6/50
# 5387/5387 [==============================] - 3s 536us/sample - loss: 0.6459 - val_loss: 0.6469
# Epoch 7/50
# 5387/5387 [==============================] - 3s 550us/sample - loss: 0.6319 - val_loss: 0.6355
# Epoch 8/50
# 5387/5387 [==============================] - 3s 534us/sample - loss: 0.6147 - val_loss: 0.6253
# Epoch 9/50
# 5387/5387 [==============================] - 3s 551us/sample - loss: 0.5988 - val_loss: 0.6236
# Epoch 10/50
# 5387/5387 [==============================] - 3s 546us/sample - loss: 0.5867 - val_loss: 0.6151
# Epoch 11/50
# 5387/5387 [==============================] - 3s 558us/sample - loss: 0.5688 - val_loss: 0.6141
# Epoch 12/50
# 5387/5387 [==============================] - 3s 561us/sample - loss: 0.5585 - val_loss: 0.5992
# Epoch 13/50
# 5387/5387 [==============================] - 3s 559us/sample - loss: 0.5441 - val_loss: 0.6018
# Epoch 14/50
# 5387/5387 [==============================] - 3s 579us/sample - loss: 0.5295 - val_loss: 0.6033
# Epoch 15/50
# 5387/5387 [==============================] - 3s 577us/sample - loss: 0.5176 - val_loss: 0.5903
# Epoch 16/50
# 5387/5387 [==============================] - 3s 582us/sample - loss: 0.5016 - val_loss: 0.5867
# Epoch 17/50
# 5387/5387 [==============================] - 3s 593us/sample - loss: 0.4900 - val_loss: 0.5863
# Epoch 18/50
# 5387/5387 [==============================] - 3s 587us/sample - loss: 0.4721 - val_loss: 0.5875
# Epoch 19/50
# 5387/5387 [==============================] - 3s 576us/sample - loss: 0.4599 - val_loss: 0.5896
# Epoch 20/50
# 5387/5387 [==============================] - 3s 587us/sample - loss: 0.4452 - val_loss: 0.5916
# Epoch 21/50
# 5387/5387 [==============================] - 3s 587us/sample - loss: 0.4285 - val_loss: 0.6062
# Epoch 22/50
# 5387/5387 [==============================] - 3s 584us/sample - loss: 0.4106 - val_loss: 0.6100
# Epoch 23/50
# 5387/5387 [==============================] - 3s 606us/sample - loss: 0.3859 - val_loss: 0.6065
# Epoch 24/50
# 5387/5387 [==============================] - 3s 588us/sample - loss: 0.3719 - val_loss: 0.6182
# Epoch 25/50
# 5387/5387 [==============================] - 3s 592us/sample - loss: 0.3566 - val_loss: 0.6232
# Epoch 26/50
# 5387/5387 [==============================] - 3s 584us/sample - loss: 0.3345 - val_loss: 0.6287
# Epoch 27/50
# 5387/5387 [==============================] - 3s 587us/sample - loss: 0.3108 - val_loss: 0.6516
# Epoch 28/50
# 5387/5387 [==============================] - 3s 595us/sample - loss: 0.3017 - val_loss: 0.6665
# Epoch 29/50
# 5387/5387 [==============================] - 3s 579us/sample - loss: 0.2803 - val_loss: 0.6682
# Epoch 30/50
# 5387/5387 [==============================] - 3s 604us/sample - loss: 0.2618 - val_loss: 0.6923
# Epoch 31/50
# 5387/5387 [==============================] - 3s 582us/sample - loss: 0.2398 - val_loss: 0.7033
# Epoch 32/50
# 5387/5387 [==============================] - 3s 579us/sample - loss: 0.2249 - val_loss: 0.7510
# Epoch 33/50
# 5387/5387 [==============================] - 3s 602us/sample - loss: 0.2017 - val_loss: 0.7439
# Epoch 34/50
# 5387/5387 [==============================] - 3s 583us/sample - loss: 0.1859 - val_loss: 0.7738
# Epoch 35/50
# 5387/5387 [==============================] - 3s 581us/sample - loss: 0.1753 - val_loss: 0.9589
# Epoch 36/50
# 5387/5387 [==============================] - 3s 576us/sample - loss: 0.1647 - val_loss: 0.8619
# Epoch 37/50
# 5387/5387 [==============================] - 3s 584us/sample - loss: 0.1462 - val_loss: 0.9340
# Epoch 38/50
# 5387/5387 [==============================] - 3s 577us/sample - loss: 0.1368 - val_loss: 0.8423
# Epoch 39/50
# 5387/5387 [==============================] - 3s 605us/sample - loss: 0.1292 - val_loss: 0.8851
# Epoch 40/50
# 5387/5387 [==============================] - 3s 583us/sample - loss: 0.1222 - val_loss: 0.9336
# Epoch 41/50
# 5387/5387 [==============================] - 3s 581us/sample - loss: 0.1087 - val_loss: 0.9101
# Epoch 42/50
# 5387/5387 [==============================] - 3s 591us/sample - loss: 0.1031 - val_loss: 0.9451
# Epoch 43/50
# 5387/5387 [==============================] - 3s 595us/sample - loss: 0.0960 - val_loss: 0.9969
# Epoch 44/50
# 5387/5387 [==============================] - 3s 587us/sample - loss: 0.0906 - val_loss: 0.9795
# Epoch 45/50
# 5387/5387 [==============================] - 3s 585us/sample - loss: 0.0811 - val_loss: 1.0852
# Epoch 46/50
# 5387/5387 [==============================] - 3s 585us/sample - loss: 0.0805 - val_loss: 1.0564
# Epoch 47/50
# 5387/5387 [==============================] - 3s 579us/sample - loss: 0.0724 - val_loss: 1.0648
# Epoch 48/50
# 5387/5387 [==============================] - 3s 603us/sample - loss: 0.0688 - val_loss: 1.0648
# Epoch 49/50
# 5387/5387 [==============================] - 3s 612us/sample - loss: 0.0680 - val_loss: 1.0575
# Epoch 50/50
# 5387/5387 [==============================] - 3s 581us/sample - loss: 0.0637 - val_loss: 1.0951

# %% [markdown]
# ## Training Plots
#
# It's often common to monitor the loss function throughout to make sure your deep learning network is progressing as expected.  Typically, you should see the loss start out high, and gradually slope to a plateau.  If the slope is too steep, it could meant the learning rate is too high.  If it's more linear, than your learning rate could be too low.
#
# In every trainined model there is a `History` object with a `history` attibute containg the loss after each epoch.  This information can by used to make the training plot.

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot(range(EPOCHS), model.history.history['loss'], c='k', label='training')
ax.plot(range(EPOCHS), model.history.history['val_loss'], c='k', label='validation')

ax.set_ylabel('loss')
ax.set_xlabel('epochs')
ax.legend()
plt.show()

# %% [markdown]
# We can calcuate the statistics on both the validation set to assess model performance as we did before in the QSAR module.
#
# First we use our model to predict the validation set.  Predictions are provided as probability of being toxic and we can view these for both the training compounds and the validation compounds.

# %%
train_predictions = model.predict(X_train)
val_predictions =  model.predict(X_val)

train_predictions = pd.DataFrame([train_predictions[:, 0], y_train], index=['Prediction', 'Toxic Class']).T   
val_predictions = pd.DataFrame([val_predictions[:, 0], y_val], index=['Prediction', 'Toxic Class']).T

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 10))

palette = {
    1: (1, 0, 0, 0.8),
    0: (0, 0, 0, 0.8)
}


sns.set()
sns.set_context('poster')

sns.kdeplot(data=train_predictions, x="Prediction", hue='Toxic Class', palette=palette, fill=True, alpha=0.3)
sns.rugplot(data=train_predictions, x="Prediction", hue='Toxic Class', palette=palette)

ax.set_title('Training Set Predictions', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Training Set Predictions')

# %%
fig, ax = plt.subplots(figsize=(10, 10))

sns.kdeplot(data=val_predictions, x="Prediction", hue='Toxic Class', palette=palette, fill=True, alpha=0.3)
sns.rugplot(data=val_predictions, x="Prediction", hue='Toxic Class', palette=palette)

ax.set_title('Validation Set Predictions', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Validation Set Predictions')

# %%
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score

def calc_stats(preds_frame):
    preds_copy = preds_frame.copy()
    preds_copy.loc[preds_frame['Prediction'] > 0.5, 'Prediction'] = 1
    preds_copy.loc[preds_frame['Prediction'] <= 0.5, 'Prediction'] = 0
    
    accuracy = accuracy_score(preds_copy['Toxic Class'], preds_copy['Prediction'])
    sens = recall_score(preds_copy['Toxic Class'], preds_copy['Prediction'])
    spec = recall_score(preds_copy['Toxic Class'], preds_copy['Prediction'], pos_label=0)
    auc = roc_auc_score(preds_copy['Toxic Class'], preds_copy['Prediction'])
    
    return {"accuracy": accuracy, "sensitivity": sens, "specificity": spec, "AUROC": auc}

training_stats = calc_stats(train_predictions)
validation_stats = calc_stats(val_predictions)

for _ in range(2): print("")

print(" TRAINING SET STATISTICS ")
for stat, val in training_stats.items():
    print(f" {stat.upper()} is {val} ")

for _ in range(2): print("")
    
print(" VALIDATION SET STATISTICS ")
for stat, val in validation_stats.items():
    print(f" {stat.upper()} is {val} ")
# Out:
#  TRAINING SET STATISTICS
#  ACCURACY is 0.9909040282160757
#  SENSITIVITY is 0.9914316315601571
#  SPECIFICITY is 0.9903325599381284
#  AUROC is 0.9908820957491427
#
#
#  VALIDATION SET STATISTICS
#  ACCURACY is 0.7037861915367484
#  SENSITIVITY is 0.7455621301775148
#  SPECIFICITY is 0.6616989567809239
#  AUROC is 0.7036305434792194
